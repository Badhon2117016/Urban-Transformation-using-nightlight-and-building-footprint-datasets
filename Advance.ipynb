# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
print(client.dashboard_link)
# Out:
# http://127.0.0.1:8787/status

# %%
# Jamaica
country_code = "BGD"

# %%
local_path = "./data/"

# %%
bldg_ddf = get_google_microsoft_bldgs(country_code, local_path, blocksize = "256M")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bldg_ddf = get_google_microsoft_bldgs(country_code, local_path, blocksize = "256M")
#
# NameError: name 'get_google_microsoft_bldgs' is not defined

# %%
bldg_ddf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bldg_ddf
#
# NameError: name 'bldg_ddf' is not defined

# %%
from utils import get_gdam_json

# %%
boundaries = get_gdam_json(country_code = country_code, admin_level=1)

# %%
boundaries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
boundaries.head()
# Out:
#      GID_1 GID_0     COUNTRY      Parish  ... CC_1 HASC_1 ISO_1                                           geometry
# 0  BGD.1_1   BGD  Bangladesh     Barisal  ...   10  BD.BA    NA  MULTIPOLYGON (((90.7709 21.8597, 90.7715 21.85...
# 1  BGD.2_1   BGD  Bangladesh  Chittagong  ...   20  BD.CG    NA  MULTIPOLYGON (((91.2736 22.5817, 91.2722 22.57...
# 2  BGD.3_1   BGD  Bangladesh       Dhaka  ...   30  BD.DH  BD-C  MULTIPOLYGON (((90.2332 23.0147, 90.234 23.027...
# 3  BGD.4_1   BGD  Bangladesh      Khulna  ...   40  BD.KH  BD-D  MULTIPOLYGON (((89.2879 21.7727, 89.2877 21.77...
# 4  BGD.8_1   BGD  Bangladesh  Mymensingh  ...   NA  BD.MM    NA  MULTIPOLYGON (((90.4948 24.3144, 90.4876 24.31...
#
# [5 rows x 12 columns]

# %%
bldg_ddf_w_boundaries = bldg_ddf.sjoin(boundaries, how="inner", predicate="intersects")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 bldg_ddf_w_boundaries = bldg_ddf.sjoin(boundaries, how="inner", predicate="intersects")
#
# NameError: name 'bldg_ddf' is not defined

# %%
bldg_ddf_w_boundaries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bldg_ddf_w_boundaries
#
# NameError: name 'bldg_ddf_w_boundaries' is not defined

# %%
buildigs_per_parish = bldg_ddf_w_boundaries["Parish"].value_counts().compute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 buildigs_per_parish = bldg_ddf_w_boundaries["Parish"].value_counts().compute()
#
# NameError: name 'bldg_ddf_w_boundaries' is not defined

# %%
buildigs_per_parish
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 buildigs_per_parish
#
# NameError: name 'buildigs_per_parish' is not defined

# %%
print(f"Total number of buildings is {buildigs_per_parish.sum()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(f"Total number of buildings is {buildigs_per_parish.sum()}")
#
# NameError: name 'buildigs_per_parish' is not defined
